# %% [markdown]
# # Example of calling PRIMAT from within python, and then reading the results which were stored in a .csv file.

# %%
import subprocess
import os
import numpy as np
import csv
import matplotlib.pyplot as plt

# Set rcParams for LaTeX rendering
plt.rcParams.update({
    "text.usetex": True,
    "font.family": "serif",
    "font.serif": ["Computer Modern"],
    "lines.linewidth": 0.8,
    "figure.figsize": (6.8,5.2),
    #"xtick.labelsize": 8,
    #"ytick.labelsize": 8,
    #"axes.labelsize": 9,
    "ytick.right": True,
    "xtick.top": True,
    "ytick.direction": "in",
    "xtick.direction": "in",
})

currentdirectory = os.getcwd()
print(currentdirectory)
# Out:
# /Users/jfroustey/Dropbox/PRIMAT2025/PythonInterface

# %%
filem = 'PyPRIMAT_FinalAbundances.m' #Input file which will load PRIMAT and dump the results in a csv file
desiredoutput = currentdirectory+"/He4DH.csv" #Name of the csv file used for output

# Modify to match the location of Mathematica Kernel
MathKernelCommand = '/Applications/Wolfram.app/Contents/MacOS/MathKernel'
#MathKernelCommand = '/Applications/Mathematica.app/Contents/MacOS/MathKernel'

# %% [markdown]
# ### Tools to prepare arguments which will be sent to Mathematica, and for calling PRIMAT inside Mathematica

# %%
#This function converts a number in python/fortran format into a string that Mathematica can understand and convert to a number in Mathematica format
def stringfromnumeric(number):
    if isinstance(number,float):
        return "Interpreter[\"Number\"][StringDelete[\""+str(number)+"\",\" \"]]"
    else:
        return number

# %%
def RunPRIMAT(DictArgs, filem, desiredoutput, MathKernelCommand):
    #This dictionary is packaged into a string which will be used as an argument to the Mathematica Kernel
    stringitems = [f"{key}={stringfromnumeric(value)}" for key, value in DictArgs.items()]

    ExtraArgumentsString = "; ".join(stringitems)+";"
    print(ExtraArgumentsString)
    
    #Outputfile is set to the desired output for Mathematica (as a string argument)
    optionoutput = "$Outputfile=\""+desiredoutput+"\""
    
    # Then we call the Mathematica script
    # We have two arguments to the Mathematica script
    # 1) the ExtraArgumentsString which is a list of variables to update wrt the default ones before running the solver
    # 2) The name of the output file in which the script writes a dictionary of the results
    return subprocess.call([MathKernelCommand,"-initfile",filem,ExtraArgumentsString,optionoutput])

# %% [markdown]
# ### Basic example which runs PRIMAT and reads final abundances

# %%
#Dictionary of parmameters and variables which needs to be overwritten wrt default parameters of PRIMAT.
DictArgs = {"$ReducedNetwork":True, 
            #"Meanh2\\[CapitalOmega]b0":0.022425,
            #"Mean\\[Tau]neutron":700.4,
            "Nrelat":0.,
            #"$RecomputeWeakRates":True,
            }

# %%
RunPRIMAT(DictArgs,filem,desiredoutput,MathKernelCommand)
# Out:
# $ReducedNetwork=True; Nrelat=Interpreter["Number"][StringDelete["0.0"," "]];
# Mathematica 13.2.0 Kernel for Mac OS X x86 (64-bit)
# Copyright 1988-2022 Wolfram Research, Inc.
# Mathematica was called from directory
#
# >   /Users/jfroustey/Dropbox/PRIMAT2025/PythonInterface
# We are now setting to this directory to call PRIMAT
# Current directory is , /Users/jfroustey/Dropbox/PRIMAT2025
# Extra arguments are {$ReducedNetwork=True;\
#
# >     Nrelat=Interpreter["Number"][StringDelete["0.0"," "]];,
#
# >    $Outputfile="/Users/jfroustey/Dropbox/PRIMAT2025/PythonInterface/He4DH.c\
#
# >     sv"}
# I will now call PRIMAT-Main.m
#
# The current Directory is /Users/jfroustey/Dropbox/PRIMAT2025
#
# Out::intm: Machine-sized integer expected at position 1 in Out[-1 + $Line].
# $ReducedNetwork True
# Meanh2Ωb0 0.022425
# I have finished with the BBN network in 31.3589
#
# >    s. and I will output in file :
#
# >   /Users/jfroustey/Dropbox/PRIMAT2025/PythonInterface/He4DH.csv
# Results are {{Neff, 3.04398}, {YP, 0.247007}, {D/H, 0.0000243586},
#
#                                               -10                 -11
# >    {He3/H, 0.0000103936}, {Li7/H, 5.56135 10   }, {n, 7.15555 10   },
#
#                                                      -8
# >    {p, 0.752932}, {d, 0.0000183404}, {t, 5.83964 10  },
#
#                      -6                                   -11
# >    {He3, 7.76725 10  }, {a, 0.0617518}, {Li7, 2.18041 10   },
#
#                      -10
# >    {Be7, 3.96928 10   }}
# 0

# %%
def ReadFinalresults(desiredoutput):
    with open(desiredoutput, mode='r', newline='') as csv_file:
        reader = csv.reader(csv_file)
        
        # Initialize an empty dictionary
        results = {}
        
        # Read each row and convert the values to float
        for row in reader:
            key = row[0]
            value = float(row[1])
            results[key] = value

    return results

# %%
ReadFinalresults(desiredoutput)
# Out:
# {'Neff': 3.0439772985579183,
#  'YP': 0.24700737277372536,
#  'D/H': 2.435855743489225e-05,
#  'He3/H': 1.0393562055230554e-05,
#  'Li7/H': 5.56135486633952e-10,
#  'n': 7.155548816062922e-11,
#  'p': 0.7529324665769664,
#  'd': 1.834034873171013e-05,
#  't': 5.839636929685692e-08,
#  'He3': 7.76725394546865e-06,
#  'a': 0.06175184319343134,
#  'Li7': 2.180404799060965e-11,
#  'Be7': 3.9692841571167344e-10}

# %% [markdown]
# ## Using Parthenope rates for d+d reactions

# %%
#Dictionary of parmameters and variables which needs to be overwritten wrt default parameters of PRIMAT.
DictArgs = {"$ReducedNetwork":True, 
            #"Meanh2\\[CapitalOmega]b0":0.022425,
            #"Mean\\[Tau]neutron":700.4,
            "Nrelat":0.,
            "$Parthenope":True,
            #"$RecomputeWeakRates":True,
            }

desiredoutputParthenope = currentdirectory+"/He4DH_Parthenope.csv" #Name of the csv file used for output

RunPRIMAT(DictArgs,filem,desiredoutputParthenope,MathKernelCommand)

ReadFinalresults(desiredoutputParthenope)
# Out:
# $ReducedNetwork=True; Nrelat=Interpreter["Number"][StringDelete["0.0"," "]]; $Parthenope=True;
# Mathematica 13.2.0 Kernel for Mac OS X x86 (64-bit)
# Copyright 1988-2022 Wolfram Research, Inc.
# Mathematica was called from directory
#
# >   /Users/jfroustey/Dropbox/PRIMAT2025/PythonInterface
# We are now setting to this directory to call PRIMAT
# Current directory is , /Users/jfroustey/Dropbox/PRIMAT2025
# Extra arguments are {$ReducedNetwork=True;\
#
# >     Nrelat=Interpreter["Number"][StringDelete["0.0"," "]]; $Parthenope=True;
#
# >     , $Outputfile="/Users/jfroustey/Dropbox/PRIMAT2025/PythonInterface/He4D\
#
# >     H_Parthenope.csv"}
# I will now call PRIMAT-Main.m
#
# The current Directory is /Users/jfroustey/Dropbox/PRIMAT2025
#
# Out::intm: Machine-sized integer expected at position 1 in Out[-1 + $Line].
# $ReducedNetwork True
# Meanh2Ωb0 0.022425
#
# NIntegrate::izero:
#    Integral and error estimates are 0 on all integration subregions. Try
#     increasing the value of the MinRecursion option. If value of integral may
#     be 0, specify a finite value for the AccuracyGoal option.

# %% [markdown]
# ## More advanced example which computes abundances on a grid of $\eta$ values (baryon to photon ratio), and computes error with a Monte Carlo on nuclear rates

# %%
fileeta = 'PyPRIMAT-Abundances-Eta.m' #Input file which will load PRIMAT and dump the results in a csv file
desiredoutput = currentdirectory+"/YiEta.csv" #Name of the csv file used for output

# %%
# Generate the range of eta values
leta_values = np.linspace(-10, -9, 50)
eta_values = np.array([10**leta for leta in leta_values])
eta_values
# Out:
# array([1.00000000e-10, 1.04811313e-10, 1.09854114e-10, 1.15139540e-10,
#        1.20679264e-10, 1.26485522e-10, 1.32571137e-10, 1.38949549e-10,
#        1.45634848e-10, 1.52641797e-10, 1.59985872e-10, 1.67683294e-10,
#        1.75751062e-10, 1.84206997e-10, 1.93069773e-10, 2.02358965e-10,
#        2.12095089e-10, 2.22299648e-10, 2.32995181e-10, 2.44205309e-10,
#        2.55954792e-10, 2.68269580e-10, 2.81176870e-10, 2.94705170e-10,
#        3.08884360e-10, 3.23745754e-10, 3.39322177e-10, 3.55648031e-10,
#        3.72759372e-10, 3.90693994e-10, 4.09491506e-10, 4.29193426e-10,
#        4.49843267e-10, 4.71486636e-10, 4.94171336e-10, 5.17947468e-10,
#        5.42867544e-10, 5.68986603e-10, 5.96362332e-10, 6.25055193e-10,
#        6.55128557e-10, 6.86648845e-10, 7.19685673e-10, 7.54312006e-10,
#        7.90604321e-10, 8.28642773e-10, 8.68511374e-10, 9.10298178e-10,
#        9.54095476e-10, 1.00000000e-09])

# %%
def ComputeMCEtaGrid(eta_values, NumMCPoints):
    results = []
    for eta in eta_values:
        dictarg= {"Eta":eta,"LengthMC":NumMCPoints,"$ReducedNetwork":True,"$ParallelBool":True}
        RunPRIMAT(dictarg,fileeta,desiredoutput,MathKernelCommand)
        resonMC = np.loadtxt(desiredoutput,delimiter=',')
        print('python read results are', resonMC)
        result_2d = resonMC
        results.append(result_2d)
    result_3d = np.array(results)
    return result_3d

# %%
NumMCPoints=50
results=ComputeMCEtaGrid(eta_values,NumMCPoints)
# Out:
# Eta=Interpreter["Number"][StringDelete["1e-10"," "]]; LengthMC=50; $ReducedNetwork=True; $ParallelBool=True;
# Wolfram 14.1.0 Kernel for Mac OS X ARM (64-bit)
# Copyright 1988-2024 Wolfram Research, Inc.
# Current directory is now, /Users/pitrou/Dropbox/iap/notebooks/PRIMAT2024
# For info the outputfile is /Users/pitrou/Dropbox/iap/notebooks/PRIMAT2024/Pyt\
#
# >    honInterface/YiEta.csv
# I will now call PRIMAT-Main.m
#
# The current Directory is /Users/pitrou/Dropbox/iap/notebooks/PRIMAT2024
#
# Out::intm: Machine-sized integer expected at position 1 in Out[-1 + $Line].
# I have finished calling PRIMAT-Main.m
#
#             -10
# Eta is 1. 10
# LengthMC is 50
#                       7
# Ωbh2Overη 3.65299 10
# Reaction file used is : BBNRatesAC2022_small_network.dat
# Running a Monte-Carlo with 50 points.
# Number of Kernels 8
# (kernel 1):
# Loading plasma results.
#
# (kernel 2):
# Loading plasma results.
#
# (kernel 3):
# Loading plasma results.
#
# (kernel 4):
# Loading plasma results.
#
# (kernel 5):
# Loading plasma results.
#
# (kernel 6):
# Loading plasma results.
#
# (kernel 7):
# Loading plasma results.
#
# (kernel 8):
# Loading plasma results.
#
# (kernel 2):
# Loading NEVO
#
# (kernel 8):
# Loading NEVO
#
# (kernel 1):
# Loading NEVO
#
# (kernel 4):
# Loading NEVO
#
# (kernel 5):
# Loading NEVO
#
# (kernel 6):
# Loading NEVO
#
# (kernel 7):
# Loading NEVO
#
# (kernel 3):
# Loading NEVO
#
# (kernel 5):
# Computing incomplete decoupling of neutrinos.
#
# (kernel 2):
# Computing incomplete decoupling of neutrinos.
#
# (kernel 6):
# Computing incomplete decoupling of neutrinos.
#
# (kernel 7):
# Computing incomplete decoupling of neutrinos.
#
# (kernel 8):
# Computing incomplete decoupling of neutrinos.
#
# (kernel 4):
# Computing incomplete decoupling of neutrinos.
#
# (kernel 1):
# Computing incomplete decoupling of neutrinos.
#
# (kernel 3):
# Computing incomplete decoupling of neutrinos.
#
# (kernel 5):
# Infer a<->t relations
#
# (kernel 2):
# Infer a<->t relations
#
# (kernel 6):
# Infer a<->t relations
#
# (kernel 8):
# Infer a<->t relations
#
# (kernel 4):
# Infer a<->t relations
#
# (kernel 7):
# Infer a<->t relations
#
# (kernel 1):
# Infer a<->t relations
#
# (kernel 3):
# Infer a<->t relations
#
# (kernel 5):
# Loading weak rates for n<->p conversions.
#
# (kernel 6):
# Loading weak rates for n<->p conversions.
#
# (kernel 4):
# Loading weak rates for n<->p conversions.
#
# (kernel 8):
# Loading weak rates for n<->p conversions.
#
# (kernel 3):
# Loading weak rates for n<->p conversions.
#
# (kernel 7):
# Loading weak rates for n<->p conversions.
#
# (kernel 1):
# Loading weak rates for n<->p conversions.
#
# (kernel 2):
# Loading weak rates for n<->p conversions.
#
# (kernel 8):
# Loading rates and bulding reactions.
#
# (kernel 5):
# Loading rates and bulding reactions.
#
# (kernel 6):
# Loading rates and bulding reactions.
#
# (kernel 2):
# Loading rates and bulding reactions.
#
# (kernel 3):
# Loading rates and bulding reactions.
#
# (kernel 4):
# Loading rates and bulding reactions.
#
# (kernel 7):
# Loading rates and bulding reactions.
#
# (kernel 1):
# Loading rates and bulding reactions.
#
# (kernel 8):
# Reaction Number   Reaction Name   Initial species   Final Species
#
# >    Reference
#
# 0                 n -> p          {n}               {p}            \
#
# >   Phys.Rept\
#
# >    . 754 (2018) 1-66
#
# 1                 np -> dg        {n, p}            {d, g}
#
# >    And06
#
# 2                 dp -> He3g      {d, p}            {He3, g}
#
# >    Moscoso2021
#
# 3                 dd -> He3n      {d, d}            {He3, n}
#
# >    Gom17
#
# 4                 dd -> tp        {d, d}            {t, p}
#
# >    Gom17
#
# 5                 tp -> ag        {t, p}            {a, g}
#
# >    Ser04
#
# 6                 td -> an        {t, d}            {a, n}
#
# >    deSouza19a
#
# 7                 ta -> Li7g      {t, a}            {Li7, g}
#
# >    DAACV04
#
# 8                 He3n -> tp      {He3, n}          {t, p}
#
# >    DAACV04
#
# 9                 He3d -> ap      {He3, d}          {a, p}
#
# >    deSouza19b
#
# 10                He3a -> Be7g    {He3, a}          {Be7, g}
#
# >    Ili16
#
# 11                Be7n -> Li7p    {Be7, n}          {Li7, p}
#
# >    deSouza2020
#
# 12                Li7p -> aa      {Li7, p}          {a, a}
#
# >    DAACV04
#
# (kernel 6):
# Reaction Number   Reaction Name   Initial species   Final Species
#
# >    Reference
#
# 0                 n -> p          {n}               {p}            \
#
# >   Phys.Rept\
#
# >    . 754 (2018) 1-66
#
# 1                 np -> dg        {n, p}            {d, g}
#
# >    And06
#
# 2                 dp -> He3g      {d, p}            {He3, g}
#
# >    Moscoso2021
#
# 3                 dd -> He3n      {d, d}            {He3, n}
#
# >    Gom17
#
# 4                 dd -> tp        {d, d}            {t, p}
#
# >    Gom17
#
# 5                 tp -> ag        {t, p}            {a, g}
#
# >    Ser04
#
# 6                 td -> an        {t, d}            {a, n}
#
# >    deSouza19a
#
# 7                 ta -> Li7g      {t, a}            {Li7, g}
#
# >    DAACV04
#
# 8                 He3n -> tp      {He3, n}          {t, p}
#
# >    DAACV04
#
# 9                 He3d -> ap      {He3, d}          {a, p}
#
# >    deSouza19b
#
# 10                He3a -> Be7g    {He3, a}          {Be7, g}
#
# >    Ili16
#
# 11                Be7n -> Li7p    {Be7, n}          {Li7, p}
#
# >    deSouza2020
#
# 12                Li7p -> aa      {Li7, p}          {a, a}
#
# >    DAACV04
#
# (kernel 2):
# Reaction Number   Reaction Name   Initial species   Final Species
#
# >    Reference
#
# 0                 n -> p          {n}               {p}            \
#
# >   Phys.Rept\
#
# >    . 754 (2018) 1-66
#
# 1                 np -> dg        {n, p}            {d, g}
#
# >    And06
#
# 2                 dp -> He3g      {d, p}            {He3, g}
#
# >    Moscoso2021
#
# 3                 dd -> He3n      {d, d}            {He3, n}
#
# >    Gom17
#
# 4                 dd -> tp        {d, d}            {t, p}
#
# >    Gom17
#
# 5                 tp -> ag        {t, p}            {a, g}
#
# >    Ser04
#
# 6                 td -> an        {t, d}            {a, n}
#
# >    deSouza19a
#
# 7                 ta -> Li7g      {t, a}            {Li7, g}
#
# >    DAACV04
#
# 8                 He3n -> tp      {He3, n}          {t, p}
#
# >    DAACV04
#
# 9                 He3d -> ap      {He3, d}          {a, p}
#
# >    deSouza19b
#
# 10                He3a -> Be7g    {He3, a}          {Be7, g}
#
# >    Ili16
#
# 11                Be7n -> Li7p    {Be7, n}          {Li7, p}
#
# >    deSouza2020
#
# 12                Li7p -> aa      {Li7, p}          {a, a}
#
# >    DAACV04
#
# (kernel 3):
# Reaction Number   Reaction Name   Initial species   Final Species
#
# >    Reference
#
# 0                 n -> p          {n}               {p}            \
#
# >   Phys.Rept\
#
# >    . 754 (2018) 1-66
#
# 1                 np -> dg        {n, p}            {d, g}
#
# >    And06
#
# 2                 dp -> He3g      {d, p}            {He3, g}
#
# >    Moscoso2021
#
# 3                 dd -> He3n      {d, d}            {He3, n}
#
# >    Gom17
#
# 4                 dd -> tp        {d, d}            {t, p}
#
# >    Gom17
#
# 5                 tp -> ag        {t, p}            {a, g}
#
# >    Ser04
#
# 6                 td -> an        {t, d}            {a, n}
#
# >    deSouza19a
#
# 7                 ta -> Li7g      {t, a}            {Li7, g}
#
# >    DAACV04
#
# 8                 He3n -> tp      {He3, n}          {t, p}
#
# >    DAACV04
#
# 9                 He3d -> ap      {He3, d}          {a, p}
#
# >    deSouza19b
#
# 10                He3a -> Be7g    {He3, a}          {Be7, g}
#
# >    Ili16
#
# 11                Be7n -> Li7p    {Be7, n}          {Li7, p}
#
# >    deSouza2020
#
# 12                Li7p -> aa      {Li7, p}          {a, a}
#
# >    DAACV04
#
# (kernel 4):
# Reaction Number   Reaction Name   Initial species   Final Species
#
# >    Reference
#
# 0                 n -> p          {n}               {p}            \
#
# >   Phys.Rept\
#
# >    . 754 (2018) 1-66
#
# 1                 np -> dg        {n, p}            {d, g}
#
# >    And06
#
# 2                 dp -> He3g      {d, p}            {He3, g}
#
# >    Moscoso2021
#
# 3                 dd -> He3n      {d, d}            {He3, n}
#
# >    Gom17
#
# 4                 dd -> tp        {d, d}            {t, p}
#
# >    Gom17
#
# 5                 tp -> ag        {t, p}            {a, g}
#
# >    Ser04
#
# 6                 td -> an        {t, d}            {a, n}
#
# >    deSouza19a
#
# 7                 ta -> Li7g      {t, a}            {Li7, g}
#
# >    DAACV04
#
# 8                 He3n -> tp      {He3, n}          {t, p}
#
# >    DAACV04
#
# 9                 He3d -> ap      {He3, d}          {a, p}
#
# >    deSouza19b
#
# 10                He3a -> Be7g    {He3, a}          {Be7, g}
#
# >    Ili16
#
# 11                Be7n -> Li7p    {Be7, n}          {Li7, p}
#
# >    deSouza2020
#
# 12                Li7p -> aa      {Li7, p}          {a, a}
#
# >    DAACV04
#
# (kernel 7):
# Reaction Number   Reaction Name   Initial species   Final Species
#
# >    Reference
#
# 0                 n -> p          {n}               {p}            \
#
# >   Phys.Rept\
#
# >    . 754 (2018) 1-66
#
# 1                 np -> dg        {n, p}            {d, g}
#
# >    And06
#
# 2                 dp -> He3g      {d, p}            {He3, g}
#
# >    Moscoso2021
#
# 3                 dd -> He3n      {d, d}            {He3, n}
#
# >    Gom17
#
# 4                 dd -> tp        {d, d}            {t, p}
#
# >    Gom17
#
# 5                 tp -> ag        {t, p}            {a, g}
#
# >    Ser04
#
# 6                 td -> an        {t, d}            {a, n}
#
# >    deSouza19a
#
# 7                 ta -> Li7g      {t, a}            {Li7, g}
#
# >    DAACV04
#
# 8                 He3n -> tp      {He3, n}          {t, p}
#
# >    DAACV04
#
# 9                 He3d -> ap      {He3, d}          {a, p}
#
# >    deSouza19b
#
# 10                He3a -> Be7g    {He3, a}          {Be7, g}
#
# >    Ili16
#
# 11                Be7n -> Li7p    {Be7, n}          {Li7, p}
#
# >    deSouza2020
#
# 12                Li7p -> aa      {Li7, p}          {a, a}
#
# >    DAACV04
#
# (kernel 1):
# Reaction Number   Reaction Name   Initial species   Final Species
#
# >    Reference
#
# 0                 n -> p          {n}               {p}            \
#
# >   Phys.Rept\
#
# >    . 754 (2018) 1-66
#
# 1                 np -> dg        {n, p}            {d, g}
#
# >    And06
#
# 2                 dp -> He3g      {d, p}            {He3, g}
#
# >    Moscoso2021
#
# 3                 dd -> He3n      {d, d}            {He3, n}
#
# >    Gom17
#
# 4                 dd -> tp        {d, d}            {t, p}
#
# >    Gom17
#
# 5                 tp -> ag        {t, p}            {a, g}
#
# >    Ser04
#
# 6                 td -> an        {t, d}            {a, n}
#
# >    deSouza19a
#
# 7                 ta -> Li7g      {t, a}            {Li7, g}
#
# >    DAACV04
#
# 8                 He3n -> tp      {He3, n}          {t, p}
#
# >    DAACV04
#
# 9                 He3d -> ap      {He3, d}          {a, p}
#
# >    deSouza19b
#
# 10                He3a -> Be7g    {He3, a}          {Be7, g}
#
# >    Ili16
#
# 11                Be7n -> Li7p    {Be7, n}          {Li7, p}
#
# >    deSouza2020
#
# 12                Li7p -> aa      {Li7, p}          {a, a}
#
# >    DAACV04
#
# (kernel 5):
# Reaction Number   Reaction Name   Initial species   Final Species
#
# >    Reference
#
# 0                 n -> p          {n}               {p}            \
#
# >   Phys.Rept\
#
# >    . 754 (2018) 1-66
#
# 1                 np -> dg        {n, p}            {d, g}
#
# >    And06
#
# 2                 dp -> He3g      {d, p}            {He3, g}
#
# >    Moscoso2021
#
# 3                 dd -> He3n      {d, d}            {He3, n}
#
# >    Gom17
#
# 4                 dd -> tp        {d, d}            {t, p}
#
# >    Gom17
#
# 5                 tp -> ag        {t, p}            {a, g}
#
# >    Ser04
#
# 6                 td -> an        {t, d}            {a, n}
#
# >    deSouza19a
#
# 7                 ta -> Li7g      {t, a}            {Li7, g}
#
# >    DAACV04
#
# 8                 He3n -> tp      {He3, n}          {t, p}
#
# >    DAACV04
#
# 9                 He3d -> ap      {He3, d}          {a, p}
#
# >    deSouza19b
#
# 10                He3a -> Be7g    {He3, a}          {Be7, g}
#
# >    Ili16
#
# 11                Be7n -> Li7p    {Be7, n}          {Li7, p}
#
# >    deSouza2020
#
# 12                Li7p -> aa      {Li7, p}          {a, a}
#
# >    DAACV04
#
# (kernel 8):
# Launching BBN numerics.
#
# (kernel 6):
# Launching BBN numerics.
#
# (kernel 3):
# Launching BBN numerics.
#
# (kernel 7):
# Launching BBN numerics.
#
# (kernel 1):
# Launching BBN numerics.
#
# (kernel 2):
# Launching BBN numerics.
#
# (kernel 4):
# Launching BBN numerics.
#
# (kernel 5):
# Launching BBN numerics.
#
# (kernel 8):
# I load compiled function from lib/DY18C_BBNRatesAC2022_small_network13.mx
#
# >    and the library linked is lib/DY18C_BBNRatesAC2022_small_network13.dylib
#
# (kernel 3):
# I load compiled function from lib/DY18C_BBNRatesAC2022_small_network13.mx
#
# >    and the library linked is lib/DY18C_BBNRatesAC2022_small_network13.dylib
#
# (kernel 2):
# I load compiled function from lib/DY18C_BBNRatesAC2022_small_network13.mx
#
# >    and the library linked is lib/DY18C_BBNRatesAC2022_small_network13.dylib
#
# (kernel 4):
# I load compiled function from lib/DY18C_BBNRatesAC2022_small_network13.mx
#
# >    and the library linked is lib/DY18C_BBNRatesAC2022_small_network13.dylib
#
# (kernel 6):
# I load compiled function from lib/DY18C_BBNRatesAC2022_small_network13.mx
#
# >    and the library linked is lib/DY18C_BBNRatesAC2022_small_network13.dylib
#
# (kernel 7):
# I load compiled function from lib/DY18C_BBNRatesAC2022_small_network13.mx
#
# >    and the library linked is lib/DY18C_BBNRatesAC2022_small_network13.dylib
#
# (kernel 1):
# I load compiled function from lib/DY18C_BBNRatesAC2022_small_network13.mx
#
# >    and the library linked is lib/DY18C_BBNRatesAC2022_small_network13.dylib
#
# (kernel 5):
# I load compiled function from lib/DY18C_BBNRatesAC2022_small_network13.mx
#
# >    and the library linked is lib/DY18C_BBNRatesAC2022_small_network13.dylib
#
# (kernel 3):
# I load compiled function from lib/DYC_BBNRatesAC2022_small_network13.mx
#
# >    and the library linked is lib/DYC_BBNRatesAC2022_small_network13.dylib
#
# (kernel 2):
# I load compiled function from lib/DYC_BBNRatesAC2022_small_network13.mx
#
# >    and the library linked is lib/DYC_BBNRatesAC2022_small_network13.dylib
#
# (kernel 6):
# I load compiled function from lib/DYC_BBNRatesAC2022_small_network13.mx
#
# >    and the library linked is lib/DYC_BBNRatesAC2022_small_network13.dylib
#
# (kernel 4):
# I load compiled function from lib/DYC_BBNRatesAC2022_small_network13.mx
#
# >    and the library linked is lib/DYC_BBNRatesAC2022_small_network13.dylib
#
# (kernel 7):
# I load compiled function from lib/DYC_BBNRatesAC2022_small_network13.mx
#
# >    and the library linked is lib/DYC_BBNRatesAC2022_small_network13.dylib
#
# (kernel 8):
# I load compiled function from lib/DYC_BBNRatesAC2022_small_network13.mx
#
# >    and the library linked is lib/DYC_BBNRatesAC2022_small_network13.dylib
#
# (kernel 1):
# I load compiled function from lib/DYC_BBNRatesAC2022_small_network13.mx
#
# >    and the library linked is lib/DYC_BBNRatesAC2022_small_network13.dylib
#
# (kernel 5):
# I load compiled function from lib/DYC_BBNRatesAC2022_small_network13.mx
#
# >    and the library linked is lib/DYC_BBNRatesAC2022_small_network13.dylib
#
# (kernel 3):
# Iteration 9  Memory usage = 72698352 time = 1.7824  Kernel : 3
#
# (kernel 3):
#            -9                                   -6
# {4.80797 10  , 0.777252, 0.000351868, 1.10964 10  , 0.0000269436, 0.05549,
#
#               -10            -13
# >   3.63167 10   , 7.24801 10   }
#
# (kernel 3):
# Loading plasma results.
#
# (kernel 3):
# Loading NEVO
#
# (kernel 3):
# Computing incomplete decoupling of neutrinos.
#
# (kernel 6):
# Iteration 18  Memory usage = 72695728 time = 1.93446  Kernel : 6
#
# (kernel 6):
#            -9                                   -6
# {4.77339 10  , 0.777371, 0.000351397, 1.11689 10  , 0.0000265035, 0.0554609,
#
#               -10           -13
# >   4.02399 10   , 7.1092 10   }
#
# (kernel 1):
# Iteration 1  Memory usage = 72398024 time = 1.9859  Kernel : 1
#
# (kernel 5):
# Iteration 15  Memory usage = 72359448 time = 1.97718  Kernel : 5
#
# (kernel 6):
# Loading plasma results.
#
# (kernel 1):
#            -9                                   -6
# {4.84423 10  , 0.777375, 0.000355695, 1.11311 10  , 0.0000268691, 0.0554574,
#
#               -10            -13
# >   3.91585 10   , 7.56418 10   }
#
# (kernel 5):
#            -9                                   -6
# {4.88607 10  , 0.777546, 0.000357383, 1.13292 10  , 0.0000265658, 0.0554141,
#
#               -10            -13
# >   3.80582 10   , 6.64287 10   }
#
# (kernel 1):
# Loading plasma results.
#
# (kernel 5):
# Loading plasma results.
#
# (kernel 7):
# Iteration 21  Memory usage = 72389264 time = 1.99905  Kernel : 7
#
# (kernel 8):
# Iteration 24  Memory usage = 72344808 time = 2.01391  Kernel : 8
#
# (kernel 6):
# Loading NEVO
#
# (kernel 7):
#           -9                                   -6
# {4.8441 10  , 0.777637, 0.000354217, 1.12556 10  , 0.0000267288, 0.0553928,
#
#               -10          -13
# >   3.92703 10   , 7.363 10   }
#
# (kernel 8):
#            -9                                   -6
# {4.77248 10  , 0.777316, 0.000350221, 1.12133 10  , 0.0000265655, 0.0554752,
#
#               -10            -13
# >   4.48411 10   , 7.05827 10   }
#
# (kernel 5):
# Loading NEVO
#
# (kernel 7):
# Loading plasma results.
#
# (kernel 8):
# Loading plasma results.
#
# (kernel 4):
# Iteration 12  Memory usage = 72680424 time = 2.01665  Kernel : 4
#
# (kernel 1):
# Loading NEVO
#
# (kernel 2):
# Iteration 5  Memory usage = 72663912 time = 1.97783  Kernel : 2
#
# (kernel 3):
# Infer a<->t relations
#
# (kernel 4):
#            -9                                   -6
# {4.88546 10  , 0.777296, 0.000357136, 1.12522 10  , 0.0000263189, 0.0554769,
#
#               -10            -13
# >   4.10599 10   , 7.35689 10   }
#
# (kernel 2):
#            -9                                  -6
# {4.85775 10  , 0.77705, 0.000354134, 1.10398 10  , 0.0000266105, 0.0555396,
#
#               -10            -13
# >   3.64998 10   , 6.84643 10   }
#
# (kernel 4):
# Loading plasma results.
#
# (kernel 2):
# Loading plasma results.
#
# (kernel 7):
# Loading NEVO
#
# (kernel 8):
# Loading NEVO
#
# (kernel 2):
# Loading NEVO
#
# (kernel 4):
# Loading NEVO
#
# (kernel 3):
# Loading weak rates for n<->p conversions.
#
# (kernel 5):
# Computing incomplete decoupling of neutrinos.
#
# (kernel 6):
# Computing incomplete decoupling of neutrinos.
#
# (kernel 3):
# Loading rates and bulding reactions.
#
# (kernel 1):
# Computing incomplete decoupling of neutrinos.
#
# (kernel 3):
# Reaction Number   Reaction Name   Initial species   Final Species
#
# >    Reference
#
# 0                 n -> p          {n}               {p}            \
#
# >   Phys.Rept\
#
# >    . 754 (2018) 1-66
#
# 1                 np -> dg        {n, p}            {d, g}
#
# >    And06
#
# 2                 dp -> He3g      {d, p}            {He3, g}
#
# >    Moscoso2021
#
# 3                 dd -> He3n      {d, d}            {He3, n}
#
# >    Gom17
#
# 4                 dd -> tp        {d, d}            {t, p}
#
# >    Gom17
#
# 5                 tp -> ag        {t, p}            {a, g}
#
# >    Ser04
#
# 6                 td -> an        {t, d}            {a, n}
#
# >    deSouza19a
#
# 7                 ta -> Li7g      {t, a}            {Li7, g}
#
# >    DAACV04
#
# 8                 He3n -> tp      {He3, n}          {t, p}
#
# >    DAACV04
#
# 9                 He3d -> ap      {He3, d}          {a, p}
#
# >    deSouza19b
#
# 10                He3a -> Be7g    {He3, a}          {Be7, g}
#
# >    Ili16
#
# 11                Be7n -> Li7p    {Be7, n}          {Li7, p}
#
# >    deSouza2020
#
# 12                Li7p -> aa      {Li7, p}          {a, a}
#
# >    DAACV04
#
# (kernel 8):
# Computing incomplete decoupling of neutrinos.
#
# (kernel 7):
# Computing incomplete decoupling of neutrinos.
#
# (kernel 5):
# Infer a<->t relations
#
# (kernel 2):
# Computing incomplete decoupling of neutrinos.
#
# (kernel 4):
# Computing incomplete decoupling of neutrinos.
#
# (kernel 6):
# Infer a<->t relations
#
# (kernel 1):
# Infer a<->t relations
#
# (kernel 7):
# Infer a<->t relations
#
# (kernel 2):
# Infer a<->t relations
#
# (kernel 5):
# Loading weak rates for n<->p conversions.
#
# (kernel 8):
# Infer a<->t relations
#
# (kernel 3):
# Launching BBN numerics.
#
# (kernel 5):
# Loading rates and bulding reactions.
#
# (kernel 4):
# Infer a<->t relations
#
# (kernel 6):
# Loading weak rates for n<->p conversions.
#
# (kernel 1):
# Loading weak rates for n<->p conversions.
#
# (kernel 6):
# Loading rates and bulding reactions.
#
# (kernel 7):
# Loading weak rates for n<->p conversions.
#
# (kernel 7):
# Loading rates and bulding reactions.
#
# (kernel 1):
# Loading rates and bulding reactions.
#
# (kernel 2):
# Loading weak rates for n<->p conversions.
#
# (kernel 7):
# Reaction Number   Reaction Name   Initial species   Final Species
#
# >    Reference
#
# 0                 n -> p          {n}               {p}            \
#
# >   Phys.Rept\
#
# >    . 754 (2018) 1-66
#
# 1                 np -> dg        {n, p}            {d, g}
#
# >    And06
#
# 2                 dp -> He3g      {d, p}            {He3, g}
#
# >    Moscoso2021
#
# 3                 dd -> He3n      {d, d}            {He3, n}
#
# >    Gom17
#
# 4                 dd -> tp        {d, d}            {t, p}
#
# >    Gom17
#
# 5                 tp -> ag        {t, p}            {a, g}
#
# >    Ser04
#
# 6                 td -> an        {t, d}            {a, n}
#
# >    deSouza19a
#
# 7                 ta -> Li7g      {t, a}            {Li7, g}
#
# >    DAACV04
#
# 8                 He3n -> tp      {He3, n}          {t, p}
#
# >    DAACV04
#
# 9                 He3d -> ap      {He3, d}          {a, p}
#
# >    deSouza19b
#
# 10                He3a -> Be7g    {He3, a}          {Be7, g}
#
# >    Ili16
#
# 11                Be7n -> Li7p    {Be7, n}          {Li7, p}
#
# >    deSouza2020
#
# 12                Li7p -> aa      {Li7, p}          {a, a}
#
# >    DAACV04
#
# (kernel 2):
# Loading rates and bulding reactions.
#
# (kernel 5):
# Reaction Number   Reaction Name   Initial species   Final Species
#
# >    Reference
#
# 0                 n -> p          {n}               {p}            \
#
# >   Phys.Rept\
#
# >    . 754 (2018) 1-66
#
# 1                 np -> dg        {n, p}            {d, g}
#
# >    And06
#
# 2                 dp -> He3g      {d, p}            {He3, g}
#
# >    Moscoso2021
#
# 3                 dd -> He3n      {d, d}            {He3, n}
#
# >    Gom17
#
# 4                 dd -> tp        {d, d}            {t, p}
#
# >    Gom17
#
# 5                 tp -> ag        {t, p}            {a, g}
#
# >    Ser04
#
# 6                 td -> an        {t, d}            {a, n}
#
# >    deSouza19a
#
# 7                 ta -> Li7g      {t, a}            {Li7, g}
#
# >    DAACV04
#
# 8                 He3n -> tp      {He3, n}          {t, p}
#
# >    DAACV04
#
# 9                 He3d -> ap      {He3, d}          {a, p}
#
# >    deSouza19b
#
# 10                He3a -> Be7g    {He3, a}          {Be7, g}
#
# >    Ili16
#
# 11                Be7n -> Li7p    {Be7, n}          {Li7, p}
#
# >    deSouza2020
#
# 12                Li7p -> aa      {Li7, p}          {a, a}
#
# >    DAACV04
#
# (kernel 3):
# I load compiled function from lib/DY18C_BBNRatesAC2022_small_network13.mx
#
# >    and the library linked is lib/DY18C_BBNRatesAC2022_small_network13.dylib
#
# (kernel 6):
# Reaction Number   Reaction Name   Initial species   Final Species
#
# >    Reference
#
# 0                 n -> p          {n}               {p}            \
#
# >   Phys.Rept\
#
# >    . 754 (2018) 1-66
#
# 1                 np -> dg        {n, p}            {d, g}
#
# >    And06
#
# 2                 dp -> He3g      {d, p}            {He3, g}
#
# >    Moscoso2021
#
# 3                 dd -> He3n      {d, d}            {He3, n}
#
# >    Gom17
#
# 4                 dd -> tp        {d, d}            {t, p}
#
# >    Gom17
#
# 5                 tp -> ag        {t, p}            {a, g}
#
# >    Ser04
#
# 6                 td -> an        {t, d}            {a, n}
#
# >    deSouza19a
#
# 7                 ta -> Li7g      {t, a}            {Li7, g}
#
# >    DAACV04
#
# 8                 He3n -> tp      {He3, n}          {t, p}
#
# >    DAACV04
#
# 9                 He3d -> ap      {He3, d}          {a, p}
#
# >    deSouza19b
#
# 10                He3a -> Be7g    {He3, a}          {Be7, g}
#
# >    Ili16
#
# 11                Be7n -> Li7p    {Be7, n}          {Li7, p}
#
# >    deSouza2020
#
# 12                Li7p -> aa      {Li7, p}          {a, a}
#
# >    DAACV04
#
# (kernel 8):
# Loading weak rates for n<->p conversions.
#
# (kernel 4):
# Loading weak rates for n<->p conversions.
#
# (kernel 8):
# Loading rates and bulding reactions.
#
# (kernel 1):
# Reaction Number   Reaction Name   Initial species   Final Species
#
# >    Reference
#
# 0                 n -> p          {n}               {p}            \
#
# >   Phys.Rept\
#
# >    . 754 (2018) 1-66
#
# 1                 np -> dg        {n, p}            {d, g}
#
# >    And06
#
# 2                 dp -> He3g      {d, p}            {He3, g}
#
# >    Moscoso2021
#
# 3                 dd -> He3n      {d, d}            {He3, n}
#
# >    Gom17
#
# 4                 dd -> tp        {d, d}            {t, p}
#
# >    Gom17
#
# 5                 tp -> ag        {t, p}            {a, g}
#
# >    Ser04
#
# 6                 td -> an        {t, d}            {a, n}
#
# >    deSouza19a
#
# 7                 ta -> Li7g      {t, a}            {Li7, g}
#
# >    DAACV04
#
# 8                 He3n -> tp      {He3, n}          {t, p}
#
# >    DAACV04
#
# 9                 He3d -> ap      {He3, d}          {a, p}
#
# >    deSouza19b
#
# 10                He3a -> Be7g    {He3, a}          {Be7, g}
#
# >    Ili16
#
# 11                Be7n -> Li7p    {Be7, n}          {Li7, p}
#
# >    deSouza2020
#
# 12                Li7p -> aa      {Li7, p}          {a, a}
#
# >    DAACV04
#
# (kernel 2):
# Reaction Number   Reaction Name   Initial species   Final Species
#
# >    Reference
#
# 0                 n -> p          {n}               {p}            \
#
# >   Phys.Rept\
#
# >    . 754 (2018) 1-66
#
# 1                 np -> dg        {n, p}            {d, g}
#
# >    And06
#
# 2                 dp -> He3g      {d, p}            {He3, g}
#
# >    Moscoso2021
#
# 3                 dd -> He3n      {d, d}            {He3, n}
#
# >    Gom17
#
# 4                 dd -> tp        {d, d}            {t, p}
#
# >    Gom17
#
# 5                 tp -> ag        {t, p}            {a, g}
#
# >    Ser04
#
# 6                 td -> an        {t, d}            {a, n}
#
# >    deSouza19a
#
# 7                 ta -> Li7g      {t, a}            {Li7, g}
#
# >    DAACV04
#
# 8                 He3n -> tp      {He3, n}          {t, p}
#
# >    DAACV04
#
# 9                 He3d -> ap      {He3, d}          {a, p}
#
# >    deSouza19b
#
# 10                He3a -> Be7g    {He3, a}          {Be7, g}
#
# >    Ili16
#
# 11                Be7n -> Li7p    {Be7, n}          {Li7, p}
#
# >    deSouza2020
#
# 12                Li7p -> aa      {Li7, p}          {a, a}
#
# >    DAACV04
#
# (kernel 4):
# Loading rates and bulding reactions.
#
# (kernel 7):
# Launching BBN numerics.
#
# (kernel 8):
# Reaction Number   Reaction Name   Initial species   Final Species
#
# >    Reference
#
# 0                 n -> p          {n}               {p}            \
#
# >   Phys.Rept\
#
# >    . 754 (2018) 1-66
#
# 1                 np -> dg        {n, p}            {d, g}
#
# >    And06
#
# 2                 dp -> He3g      {d, p}            {He3, g}
#
# >    Moscoso2021
#
# 3                 dd -> He3n      {d, d}            {He3, n}
#
# >    Gom17
#
# 4                 dd -> tp        {d, d}            {t, p}
#
# >    Gom17
#
# 5                 tp -> ag        {t, p}            {a, g}
#
# >    Ser04
#
# 6                 td -> an        {t, d}            {a, n}
#
# >    deSouza19a
#
# 7                 ta -> Li7g      {t, a}            {Li7, g}
#
# >    DAACV04
#
# 8                 He3n -> tp      {He3, n}          {t, p}
#
# >    DAACV04
#
# 9                 He3d -> ap      {He3, d}          {a, p}
#
# >    deSouza19b
#
# 10                He3a -> Be7g    {He3, a}          {Be7, g}
#
# >    Ili16
#
# 11                Be7n -> Li7p    {Be7, n}          {Li7, p}
#
# >    deSouza2020
#
# 12                Li7p -> aa      {Li7, p}          {a, a}
#
# >    DAACV04
#
# (kernel 4):
# Reaction Number   Reaction Name   Initial species   Final Species
#
# >    Reference
#
# 0                 n -> p          {n}               {p}            \
#
# >   Phys.Rept\
#
# >    . 754 (2018) 1-66
#
# 1                 np -> dg        {n, p}            {d, g}
#
# >    And06
#
# 2                 dp -> He3g      {d, p}            {He3, g}
#
# >    Moscoso2021
#
# 3                 dd -> He3n      {d, d}            {He3, n}
#
# >    Gom17
#
# 4                 dd -> tp        {d, d}            {t, p}
#
# >    Gom17
#
# 5                 tp -> ag        {t, p}            {a, g}
#
# >    Ser04
#
# 6                 td -> an        {t, d}            {a, n}
#
# >    deSouza19a
#
# 7                 ta -> Li7g      {t, a}            {Li7, g}
#
# >    DAACV04
#
# 8                 He3n -> tp      {He3, n}          {t, p}
#
# >    DAACV04
#
# 9                 He3d -> ap      {He3, d}          {a, p}
#
# >    deSouza19b
#
# 10                He3a -> Be7g    {He3, a}          {Be7, g}
#
# >    Ili16
#
# 11                Be7n -> Li7p    {Be7, n}          {Li7, p}
#
# >    deSouza2020
#
# 12                Li7p -> aa      {Li7, p}          {a, a}
#
# >    DAACV04
#
# (kernel 7):
# I load compiled function from lib/DY18C_BBNRatesAC2022_small_network13.mx
#
# >    and the library linked is lib/DY18C_BBNRatesAC2022_small_network13.dylib
#
# (kernel 5):
# Launching BBN numerics.
#
# (kernel 6):
# Launching BBN numerics.
#
# (kernel 3):
# I load compiled function from lib/DYC_BBNRatesAC2022_small_network13.mx
#
# >    and the library linked is lib/DYC_BBNRatesAC2022_small_network13.dylib
#
# (kernel 1):
# Launching BBN numerics.
#
# (kernel 2):
# Launching BBN numerics.
#
# (kernel 8):
# Launching BBN numerics.
#
# (kernel 5):
# I load compiled function from lib/DY18C_BBNRatesAC2022_small_network13.mx
#
# >    and the library linked is lib/DY18C_BBNRatesAC2022_small_network13.dylib
#
# (kernel 6):
# I load compiled function from lib/DY18C_BBNRatesAC2022_small_network13.mx
#
# >    and the library linked is lib/DY18C_BBNRatesAC2022_small_network13.dylib
#
# (kernel 4):
# Launching BBN numerics.
#
# (kernel 7):
# I load compiled function from lib/DYC_BBNRatesAC2022_small_network13.mx
#
# >    and the library linked is lib/DYC_BBNRatesAC2022_small_network13.dylib
#
# (kernel 1):
# I load compiled function from lib/DY18C_BBNRatesAC2022_small_network13.mx
#
# >    and the library linked is lib/DY18C_BBNRatesAC2022_small_network13.dylib
#
# (kernel 2):
# I load compiled function from lib/DY18C_BBNRatesAC2022_small_network13.mx
#
# >    and the library linked is lib/DY18C_BBNRatesAC2022_small_network13.dylib
#
# (kernel 8):
# I load compiled function from lib/DY18C_BBNRatesAC2022_small_network13.mx
#
# >    and the library linked is lib/DY18C_BBNRatesAC2022_small_network13.dylib
#
# (kernel 4):
# I load compiled function from lib/DY18C_BBNRatesAC2022_small_network13.mx
#
# >    and the library linked is lib/DY18C_BBNRatesAC2022_small_network13.dylib
#
# (kernel 5):
# I load compiled function from lib/DYC_BBNRatesAC2022_small_network13.mx
#
# >    and the library linked is lib/DYC_BBNRatesAC2022_small_network13.dylib
#
# (kernel 6):
# I load compiled function from lib/DYC_BBNRatesAC2022_small_network13.mx
#
# >    and the library linked is lib/DYC_BBNRatesAC2022_small_network13.dylib
#
# (kernel 1):
# I load compiled function from lib/DYC_BBNRatesAC2022_small_network13.mx
#
# >    and the library linked is lib/DYC_BBNRatesAC2022_small_network13.dylib
#
# (kernel 2):
# I load compiled function from lib/DYC_BBNRatesAC2022_small_network13.mx
#
# >    and the library linked is lib/DYC_BBNRatesAC2022_small_network13.dylib
#
# (kernel 8):
# I load compiled function from lib/DYC_BBNRatesAC2022_small_network13.mx
#
# >    and the library linked is lib/DYC_BBNRatesAC2022_small_network13.dylib
#
# (kernel 4):
# I load compiled function from lib/DYC_BBNRatesAC2022_small_network13.mx
#
# >    and the library linked is lib/DYC_BBNRatesAC2022_small_network13.dylib
#
# (kernel 3):
# Iteration 10  Memory usage = 73152024 time = 1.43429  Kernel : 3
#
# (kernel 3):
#            -9                                   -6
# {4.91788 10  , 0.777494, 0.000360071, 1.11858 10  , 0.0000263191, 0.0554258,
#
#               -10            -13
# >   4.06538 10   , 6.74623 10   }
#
# (kernel 3):
# Loading plasma results.
#
# (kernel 3):
# Loading NEVO
#
# (kernel 7):
# Iteration 22  Memory usage = 72876488 time = 1.3858  Kernel : 7
#
# (kernel 7):
#            -9                                   -6
# {4.82029 10  , 0.777494, 0.000353668, 1.10354 10  , 0.000027118, 0.0554286,
#
#               -10            -13
# >   3.94971 10   , 7.70561 10   }
#
# (kernel 7):
# Loading plasma results.
#
# (kernel 7):
# Loading NEVO
#
# (kernel 6):
# Iteration 19  Memory usage = 73175832 time = 1.46279  Kernel : 6
#
# (kernel 6):
#            -9                                   -6
# {4.83096 10  , 0.777396, 0.000355012, 1.11553 10  , 0.00002649, 0.0554529,
#
#              -10            -13
# >   4.0875 10   , 7.48357 10   }
#
# (kernel 3):
# Computing incomplete decoupling of neutrinos.
#
# (kernel 6):
# Loading plasma results.
#
# (kernel 6):
# Loading NEVO
#
# (kernel 2):
# Iteration 6  Memory usage = 73182464 time = 1.40512  Kernel : 2
#
# (kernel 2):
#            -9                                   -6
# {4.79635 10  , 0.777179, 0.000352292, 1.11032 10  , 0.0000270299, 0.0555081,
#
#               -10            -13
# >   3.82247 10   , 7.61424 10   }
#
# (kernel 5):
# Iteration 16  Memory usage = 72869960 time = 1.44351  Kernel : 5
#
# (kernel 1):
# Iteration 2  Memory usage = 72863200 time = 1.4584  Kernel : 1
#
# (kernel 2):
# Loading plasma results.
#
# (kernel 5):
#            -9                                   -6
# {4.81906 10  , 0.777389, 0.000353719, 1.10677 10  , 0.0000269522, 0.0554548,
#
#               -10            -13
# >   3.78485 10   , 7.50325 10   }
#
# (kernel 1):
#           -9                                  -6
# {4.9114 10  , 0.77747, 0.000359636, 1.12532 10  , 0.0000266656, 0.0554318,
#
#               -10            -13
# >   4.44436 10   , 7.33216 10   }
#
# (kernel 5):
# Loading plasma results.
#
# (kernel 1):
# Loading plasma results.
#
# (kernel 7):
# Computing incomplete decoupling of neutrinos.
#
# (kernel 2):
# Loading NEVO
#
# (kernel 8):
# Iteration 25  Memory usage = 72821208 time = 1.47185  Kernel : 8
#
# (kernel 6):
# Computing incomplete decoupling of neutrinos.
#
# (kernel 8):
#            -9                                   -6
# {4.83879 10  , 0.777368, 0.000355636, 1.10709 10  , 0.0000269938, 0.0554591,
#
#               -10            -13
# >   3.97683 10   , 7.41531 10   }
#
# (kernel 3):
# Infer a<->t relations
#
# (kernel 8):
# Loading plasma results.
#
# (kernel 4):
# Iteration 13  Memory usage = 73170304 time = 1.46281  Kernel : 4
#
# (kernel 4):
#            -9                                   -6
# {4.84076 10  , 0.777336, 0.000355359, 1.11481 10  , 0.0000266896, 0.0554675,
#
#              -10            -13
# >   3.9922 10   , 7.37002 10   }
#
# (kernel 5):
# Loading NEVO
#
# (kernel 1):
# Loading NEVO
#
# (kernel 4):
# Loading plasma results.
#
# (kernel 6):
# Infer a<->t relations
#
# (kernel 8):
# Loading NEVO
#
# (kernel 3):
# Loading weak rates for n<->p conversions.
#
# (kernel 4):
# Loading NEVO
#
# (kernel 7):
# Infer a<->t relations
#
# (kernel 3):
# Loading rates and bulding reactions.
#
# (kernel 1):
# Computing incomplete decoupling of neutrinos.
#
# (kernel 2):
# Computing incomplete decoupling of neutrinos.
#
# (kernel 6):
# Loading weak rates for n<->p conversions.
#
# (kernel 5):
# Computing incomplete decoupling of neutrinos.
#
# (kernel 6):
# Loading rates and bulding reactions.
#
# (kernel 3):
# Reaction Number   Reaction Name   Initial species   Final Species
#
# >    Reference
#
# 0                 n -> p          {n}               {p}            \
#
# >   Phys.Rept\
#
# >    . 754 (2018) 1-66
#
# 1                 np -> dg        {n, p}            {d, g}
#
# >    And06
#
# 2                 dp -> He3g      {d, p}            {He3, g}
#
# >    Moscoso2021
#
# 3                 dd -> He3n      {d, d}            {He3, n}
#
# >    Gom17
#
# 4                 dd -> tp        {d, d}            {t, p}
#
# >    Gom17
#
# 5                 tp -> ag        {t, p}            {a, g}
#
# >    Ser04
#
# 6                 td -> an        {t, d}            {a, n}
#
# >    deSouza19a
#
# 7                 ta -> Li7g      {t, a}            {Li7, g}
#
# >    DAACV04
#
# 8                 He3n -> tp      {He3, n}          {t, p}
#
# >    DAACV04
#
# 9                 He3d -> ap      {He3, d}          {a, p}
#
# >    deSouza19b
#
# 10                He3a -> Be7g    {He3, a}          {Be7, g}
#
# >    Ili16
#
# 11                Be7n -> Li7p    {Be7, n}          {Li7, p}
#
# >    deSouza2020
#
# 12                Li7p -> aa      {Li7, p}          {a, a}
#
# >    DAACV04
#
# (kernel 7):
# Loading weak rates for n<->p conversions.
#
# (kernel 7):
# Loading rates and bulding reactions.
#
# (kernel 8):
# Computing incomplete decoupling of neutrinos.
#
# (kernel 2):
# Infer a<->t relations
#
# (kernel 6):
# Reaction Number   Reaction Name   Initial species   Final Species
#
# >    Reference
#
# 0                 n -> p          {n}               {p}            \
#
# >   Phys.Rept\
#
# >    . 754 (2018) 1-66
#
# 1                 np -> dg        {n, p}            {d, g}
#
# >    And06
#
# 2                 dp -> He3g      {d, p}            {He3, g}
#
# >    Moscoso2021
#
# 3                 dd -> He3n      {d, d}            {He3, n}
#
# >    Gom17
#
# 4                 dd -> tp        {d, d}            {t, p}
#
# >    Gom17
#
# 5                 tp -> ag        {t, p}            {a, g}
#
# >    Ser04
#
# 6                 td -> an        {t, d}            {a, n}
#
# >    deSouza19a
#
# 7                 ta -> Li7g      {t, a}            {Li7, g}
#
# >    DAACV04
#
# 8                 He3n -> tp      {He3, n}          {t, p}
#
# >    DAACV04
#
# 9                 He3d -> ap      {He3, d}          {a, p}
#
# >    deSouza19b
#
# 10                He3a -> Be7g    {He3, a}          {Be7, g}
#
# >    Ili16
#
# 11                Be7n -> Li7p    {Be7, n}          {Li7, p}
#
# >    deSouza2020
#
# 12                Li7p -> aa      {Li7, p}          {a, a}
#
# >    DAACV04
#
# (kernel 1):
# Infer a<->t relations
#
# (kernel 4):
# Computing incomplete decoupling of neutrinos.
#
# (kernel 7):
# Reaction Number   Reaction Name   Initial species   Final Species
#
# >    Reference
#
# 0                 n -> p          {n}               {p}            \
#
# >   Phys.Rept\
#
# >    . 754 (2018) 1-66
#
# 1                 np -> dg        {n, p}            {d, g}
#
# >    And06
#
# 2                 dp -> He3g      {d, p}            {He3, g}
#
# >    Moscoso2021
#
# 3                 dd -> He3n      {d, d}            {He3, n}
#
# >    Gom17
#
# 4                 dd -> tp        {d, d}            {t, p}
#
# >    Gom17
#
# 5                 tp -> ag        {t, p}            {a, g}
#
# >    Ser04
#
# 6                 td -> an        {t, d}            {a, n}
#
# >    deSouza19a
#
# 7                 ta -> Li7g      {t, a}            {Li7, g}
#
# >    DAACV04
#
# 8                 He3n -> tp      {He3, n}          {t, p}
#
# >    DAACV04
#
# 9                 He3d -> ap      {He3, d}          {a, p}
#
# >    deSouza19b
#
# 10                He3a -> Be7g    {He3, a}          {Be7, g}
#
# >    Ili16
#
# 11                Be7n -> Li7p    {Be7, n}          {Li7, p}
#
# >    deSouza2020
#
# 12                Li7p -> aa      {Li7, p}          {a, a}
#
# >    DAACV04
#
# (kernel 5):
# Infer a<->t relations
#
# (kernel 3):
# Launching BBN numerics.
#
# (kernel 8):
# Infer a<->t relations
#
# (kernel 1):
# Loading weak rates for n<->p conversions.
#
# (kernel 2):
# Loading weak rates for n<->p conversions.
#
# (kernel 2):
# Loading rates and bulding reactions.
#
# (kernel 4):
# Infer a<->t relations
#
# (kernel 5):
# Loading weak rates for n<->p conversions.
#
# (kernel 1):
# Loading rates and bulding reactions.
#
# (kernel 5):
# Loading rates and bulding reactions.
#
# (kernel 6):
# Launching BBN numerics.
#
# (kernel 3):
# I load compiled function from lib/DY18C_BBNRatesAC2022_small_network13.mx
#
# >    and the library linked is lib/DY18C_BBNRatesAC2022_small_network13.dylib
#
# (kernel 7):
# Launching BBN numerics.
#
# (kernel 8):
# Loading weak rates for n<->p conversions.
#
# (kernel 1):
# Reaction Number   Reaction Name   Initial species   Final Species
#
# >    Reference
#
# 0                 n -> p          {n}               {p}            \
#
# >   Phys.Rept\
#
# >    . 754 (2018) 1-66
#
# 1                 np -> dg        {n, p}            {d, g}
#
# >    And06
#
# 2                 dp -> He3g      {d, p}            {He3, g}
#
# >    Moscoso2021
#
# 3                 dd -> He3n      {d, d}            {He3, n}
#
# >    Gom17
#
# 4                 dd -> tp        {d, d}            {t, p}
#
# >    Gom17
#
# 5                 tp -> ag        {t, p}            {a, g}
#
# >    Ser04
#
# 6                 td -> an        {t, d}            {a, n}
#
# >    deSouza19a
#
# 7                 ta -> Li7g      {t, a}            {Li7, g}
#
# >    DAACV04
#
# 8                 He3n -> tp      {He3, n}          {t, p}
#
# >    DAACV04
#
# 9                 He3d -> ap      {He3, d}          {a, p}
#
# >    deSouza19b
#
# 10                He3a -> Be7g    {He3, a}          {Be7, g}
#
# >    Ili16
#
# 11                Be7n -> Li7p    {Be7, n}          {Li7, p}
#
# >    deSouza2020
#
# 12                Li7p -> aa      {Li7, p}          {a, a}
#
# >    DAACV04
#
# (kernel 2):
# Reaction Number   Reaction Name   Initial species   Final Species
#
# >    Reference
#
# 0                 n -> p          {n}               {p}            \
#
# >   Phys.Rept\
#
# >    . 754 (2018) 1-66
#
# 1                 np -> dg        {n, p}            {d, g}
#
# >    And06
#
# 2                 dp -> He3g      {d, p}            {He3, g}
#
# >    Moscoso2021
#
# 3                 dd -> He3n      {d, d}            {He3, n}
#
# >    Gom17
#
# 4                 dd -> tp        {d, d}            {t, p}
#
# >    Gom17
#
# 5                 tp -> ag        {t, p}            {a, g}
#
# >    Ser04
#
# 6                 td -> an        {t, d}            {a, n}
#
# >    deSouza19a
#
# 7                 ta -> Li7g      {t, a}            {Li7, g}
#
# >    DAACV04
#
# 8                 He3n -> tp      {He3, n}          {t, p}
#
# >    DAACV04
#
# 9                 He3d -> ap      {He3, d}          {a, p}
#
# >    deSouza19b
#
# 10                He3a -> Be7g    {He3, a}          {Be7, g}
#
# >    Ili16
#
# 11                Be7n -> Li7p    {Be7, n}          {Li7, p}
#
# >    deSouza2020
#
# 12                Li7p -> aa      {Li7, p}          {a, a}
#
# >    DAACV04
#
# (kernel 5):
# Reaction Number   Reaction Name   Initial species   Final Species
#
# >    Reference
#
# 0                 n -> p          {n}               {p}            \
#
# >   Phys.Rept\
#
# >    . 754 (2018) 1-66
#
# 1                 np -> dg        {n, p}            {d, g}
#
# >    And06
#
# 2                 dp -> He3g      {d, p}            {He3, g}
#
# >    Moscoso2021
#
# 3                 dd -> He3n      {d, d}            {He3, n}
#
# >    Gom17
#
# 4                 dd -> tp        {d, d}            {t, p}
#
# >    Gom17
#
# 5                 tp -> ag        {t, p}            {a, g}
#
# >    Ser04
#
# 6                 td -> an        {t, d}            {a, n}
#
# >    deSouza19a
#
# 7                 ta -> Li7g      {t, a}            {Li7, g}
#
# >    DAACV04
#
# 8                 He3n -> tp      {He3, n}          {t, p}
#
# >    DAACV04
#
# 9                 He3d -> ap      {He3, d}          {a, p}
#
# >    deSouza19b
#
# 10                He3a -> Be7g    {He3, a}          {Be7, g}
#
# >    Ili16
#
# 11                Be7n -> Li7p    {Be7, n}          {Li7, p}
#
# >    deSouza2020
#
# 12                Li7p -> aa      {Li7, p}          {a, a}
#
# >    DAACV04
#
# (kernel 8):
# Loading rates and bulding reactions.
#
# (kernel 4):
# Loading weak rates for n<->p conversions.
#
# (kernel 6):
# I load compiled function from lib/DY18C_BBNRatesAC2022_small_network13.mx
#
# >    and the library linked is lib/DY18C_BBNRatesAC2022_small_network13.dylib
#
# (kernel 4):
# Loading rates and bulding reactions.
#
# (kernel 8):
# Reaction Number   Reaction Name   Initial species   Final Species
#
# >    Reference
#
# 0                 n -> p          {n}               {p}            \
#
# >   Phys.Rept\
#
# >    . 754 (2018) 1-66
#
# 1                 np -> dg        {n, p}            {d, g}
#
# >    And06
#
# 2                 dp -> He3g      {d, p}            {He3, g}
#
# >    Moscoso2021
#
# 3                 dd -> He3n      {d, d}            {He3, n}
#
# >    Gom17
#
# 4                 dd -> tp        {d, d}            {t, p}
#
# >    Gom17
#
# 5                 tp -> ag        {t, p}            {a, g}
#
# >    Ser04
#
# 6                 td -> an        {t, d}            {a, n}
#
# >    deSouza19a
#
# 7                 ta -> Li7g      {t, a}            {Li7, g}
#
# >    DAACV04
#
# 8                 He3n -> tp      {He3, n}          {t, p}
#
# >    DAACV04
#
# 9                 He3d -> ap      {He3, d}          {a, p}
#
# >    deSouza19b
#
# 10                He3a -> Be7g    {He3, a}          {Be7, g}
#
# >    Ili16
#
# 11                Be7n -> Li7p    {Be7, n}          {Li7, p}
#
# >    deSouza2020
#
# 12                Li7p -> aa      {Li7, p}          {a, a}
#
# >    DAACV04
#
# (kernel 7):
# I load compiled function from lib/DY18C_BBNRatesAC2022_small_network13.mx
#
# >    and the library linked is lib/DY18C_BBNRatesAC2022_small_network13.dylib
#
# (kernel 2):
# Launching BBN numerics.
#
# (kernel 4):
# Reaction Number   Reaction Name   Initial species   Final Species
#
# >    Reference
#
# 0                 n -> p          {n}               {p}            \
#
# >   Phys.Rept\
#
# >    . 754 (2018) 1-66
#
# 1                 np -> dg        {n, p}            {d, g}
#
# >    And06
#
# 2                 dp -> He3g      {d, p}            {He3, g}
#
# >    Moscoso2021
#
# 3                 dd -> He3n      {d, d}            {He3, n}
#
# >    Gom17
#
# 4                 dd -> tp        {d, d}            {t, p}
#
# >    Gom17
#
# 5                 tp -> ag        {t, p}            {a, g}
#
# >    Ser04
#
# 6                 td -> an        {t, d}            {a, n}
#
# >    deSouza19a
#
# 7                 ta -> Li7g      {t, a}            {Li7, g}
#
# >    DAACV04
#
# 8                 He3n -> tp      {He3, n}          {t, p}
#
# >    DAACV04
#
# 9                 He3d -> ap      {He3, d}          {a, p}
#
# >    deSouza19b
#
# 10                He3a -> Be7g    {He3, a}          {Be7, g}
#
# >    Ili16
#
# 11                Be7n -> Li7p    {Be7, n}          {Li7, p}
#
# >    deSouza2020
#
# 12                Li7p -> aa      {Li7, p}          {a, a}
#
# >    DAACV04
#
# (kernel 5):
# Launching BBN numerics.
#
# (kernel 1):
# Launching BBN numerics.
#
# (kernel 3):
# I load compiled function from lib/DYC_BBNRatesAC2022_small_network13.mx
#
# >    and the library linked is lib/DYC_BBNRatesAC2022_small_network13.dylib
#
# (kernel 2):
# I load compiled function from lib/DY18C_BBNRatesAC2022_small_network13.mx
#
# >    and the library linked is lib/DY18C_BBNRatesAC2022_small_network13.dylib
#
# (kernel 7):
# I load compiled function from lib/DYC_BBNRatesAC2022_small_network13.mx
#
# >    and the library linked is lib/DYC_BBNRatesAC2022_small_network13.dylib
#
# (kernel 8):
# Launching BBN numerics.
#
# (kernel 5):
# I load compiled function from lib/DY18C_BBNRatesAC2022_small_network13.mx
#
# >    and the library linked is lib/DY18C_BBNRatesAC2022_small_network13.dylib
#
# (kernel 6):
# I load compiled function from lib/DYC_BBNRatesAC2022_small_network13.mx
#
# >    and the library linked is lib/DYC_BBNRatesAC2022_small_network13.dylib
#
# (kernel 1):
# I load compiled function from lib/DY18C_BBNRatesAC2022_small_network13.mx
#
# >    and the library linked is lib/DY18C_BBNRatesAC2022_small_network13.dylib
#
# (kernel 4):
# Launching BBN numerics.
#
# (kernel 8):
# I load compiled function from lib/DY18C_BBNRatesAC2022_small_network13.mx
#
# >    and the library linked is lib/DY18C_BBNRatesAC2022_small_network13.dylib
#
# (kernel 4):
# I load compiled function from lib/DY18C_BBNRatesAC2022_small_network13.mx
#
# >    and the library linked is lib/DY18C_BBNRatesAC2022_small_network13.dylib
#
# (kernel 2):
# I load compiled function from lib/DYC_BBNRatesAC2022_small_network13.mx
#
# >    and the library linked is lib/DYC_BBNRatesAC2022_small_network13.dylib
#
# (kernel 1):
# I load compiled function from lib/DYC_BBNRatesAC2022_small_network13.mx
#
# >    and the library linked is lib/DYC_BBNRatesAC2022_small_network13.dylib
#
# (kernel 5):
# I load compiled function from lib/DYC_BBNRatesAC2022_small_network13.mx
#
# >    and the library linked is lib/DYC_BBNRatesAC2022_small_network13.dylib
#
# (kernel 8):
# I load compiled function from lib/DYC_BBNRatesAC2022_small_network13.mx
#
# >    and the library linked is lib/DYC_BBNRatesAC2022_small_network13.dylib
#
# (kernel 4):
# I load compiled function from lib/DYC_BBNRatesAC2022_small_network13.mx
#
# >    and the library linked is lib/DYC_BBNRatesAC2022_small_network13.dylib
#
# (kernel 7):
# Iteration 23  Memory usage = 73317120 time = 1.39514  Kernel : 7
#
# (kernel 7):
#            -9                                   -6
# {4.78332 10  , 0.777367, 0.000351367, 1.10938 10  , 0.0000268151, 0.0554615,
#
#               -10            -13
# >   3.85754 10   , 7.64249 10   }
#
# (kernel 7):
# Loading plasma results.
#
# (kernel 3):
# Iteration 11  Memory usage = 73635016 time = 1.43531  Kernel : 3
#
# (kernel 7):
# Loading NEVO
#
# (kernel 3):
#            -9                                   -6
# {4.86226 10  , 0.777643, 0.000357486, 1.11514 10  , 0.0000268772, 0.0553895,
#
# ...
#
# >    and the library linked is lib/DY18C_BBNRatesAC2022_small_network13.dylib
#
# (kernel 2):
# I load compiled function from lib/DY18C_BBNRatesAC2022_small_network13.mx
#
# >    and the library linked is lib/DY18C_BBNRatesAC2022_small_network13.dylib
#
# (kernel 4):
# I load compiled function from lib/DYC_BBNRatesAC2022_small_network13.mx
#
# >    and the library linked is lib/DYC_BBNRatesAC2022_small_network13.dylib
#
# (kernel 3):
# I load compiled function from lib/DY18C_BBNRatesAC2022_small_network13.mx
#
# >    and the library linked is lib/DY18C_BBNRatesAC2022_small_network13.dylib
#
# (kernel 8):
# I load compiled function from lib/DYC_BBNRatesAC2022_small_network13.mx
#
# >    and the library linked is lib/DYC_BBNRatesAC2022_small_network13.dylib
#
# (kernel 1):
# I load compiled function from lib/DY18C_BBNRatesAC2022_small_network13.mx
#
# >    and the library linked is lib/DY18C_BBNRatesAC2022_small_network13.dylib
#
# (kernel 6):
# I load compiled function from lib/DYC_BBNRatesAC2022_small_network13.mx
#
# >    and the library linked is lib/DYC_BBNRatesAC2022_small_network13.dylib
#
# (kernel 7):
# I load compiled function from lib/DYC_BBNRatesAC2022_small_network13.mx
#
# >    and the library linked is lib/DYC_BBNRatesAC2022_small_network13.dylib
#
# (kernel 2):
# I load compiled function from lib/DYC_BBNRatesAC2022_small_network13.mx
#
# >    and the library linked is lib/DYC_BBNRatesAC2022_small_network13.dylib
#
# (kernel 3):
# I load compiled function from lib/DYC_BBNRatesAC2022_small_network13.mx
#
# >    and the library linked is lib/DYC_BBNRatesAC2022_small_network13.dylib
#
# (kernel 1):
# I load compiled function from lib/DYC_BBNRatesAC2022_small_network13.mx
#
# >    and the library linked is lib/DYC_BBNRatesAC2022_small_network13.dylib
#
# (kernel 5):
# Iteration 41  Memory usage = 75848896 time = 1.94542  Kernel : 5
#
# (kernel 5):
#            -11                      -6            -8           -6
# {1.82448 10   , 0.748199, 7.61745 10  , 2.27228 10  , 6.0956 10  , 0.0629419,\
#
# >
#
#               -11            -9
# >   1.00872 10   , 1.04179 10  }
#
# (kernel 4):
# Iteration 29  Memory usage = 75828776 time = 1.91006  Kernel : 4
#
# (kernel 8):
# Iteration 38  Memory usage = 75845912 time = 1.83989  Kernel : 8
#
# (kernel 4):
#            -11                      -6            -8           -6
# {1.81024 10   , 0.748496, 7.57726 10  , 2.27587 10  , 6.0926 10  , 0.0628676,\
#
# >
#
#               -12            -9
# >   9.32827 10   , 1.01729 10  }
#
# (kernel 8):
#            -11                     -6            -8            -6
# {1.87363 10   , 0.748322, 7.6506 10  , 2.38061 10  , 6.08811 10  , 0.0629111,\
#
# >
#
#               -11            -9
# >   1.08388 10   , 1.04106 10  }
#
# (kernel 6):
# Iteration 35  Memory usage = 75524712 time = 1.92368  Kernel : 6
#
# (kernel 6):
#            -11                      -6           -8            -6
# {1.94645 10   , 0.748458, 7.78421 10  , 2.4328 10  , 5.94434 10  , 0.0628771,\
#
# >
#
#               -11            -10
# >   1.07632 10   , 9.25121 10   }
#
# (kernel 7):
# Iteration 32  Memory usage = 75504008 time = 1.91942  Kernel : 7
#
# (kernel 7):
#            -11                      -6            -8           -6
# {1.87742 10   , 0.748493, 7.67306 10  , 2.40082 10  , 5.8439 10  , 0.0628686,\
#
# >
#
#               -11            -10
# >   1.04454 10   , 9.86691 10   }
#
# (kernel 3):
# Iteration 44  Memory usage = 75856904 time = 1.8905  Kernel : 3
#
# (kernel 2):
# Iteration 46  Memory usage = 75818368 time = 1.93442  Kernel : 2
#
# (kernel 3):
#            -11                      -6            -8            -6
# {1.82321 10   , 0.748438, 7.60632 10  , 2.32942 10  , 6.13237 10  ,
#
#                          -11            -9
# >   0.0628821, 1.03943 10   , 1.04824 10  }
#
# (kernel 2):
#            -11                      -6            -8         -6
# {1.90059 10   , 0.748497, 7.80478 10  , 2.30895 10  , 5.97 10  , 0.0628674,
#
#               -12            -10
# >   9.21838 10   , 9.41423 10   }
#
# (kernel 2):
# Loading plasma results.
#
# (kernel 1):
# Iteration 49  Memory usage = 75881936 time = 1.90972  Kernel : 1
#
# (kernel 2):
# Loading NEVO
#
# (kernel 1):
#            -11                      -6            -8            -6
# {1.90494 10   , 0.748479, 7.72906 10  , 2.37302 10  , 5.97262 10  ,
#
#                          -11            -10
# >   0.0628718, 1.04619 10   , 9.88602 10   }
#
# (kernel 1):
# Loading plasma results.
#
# (kernel 1):
# Loading NEVO
#
# (kernel 2):
# Computing incomplete decoupling of neutrinos.
#
# (kernel 1):
# Computing incomplete decoupling of neutrinos.
#
# (kernel 2):
# Infer a<->t relations
#
# (kernel 1):
# Infer a<->t relations
#
# (kernel 2):
# Loading weak rates for n<->p conversions.
#
# (kernel 2):
# Loading rates and bulding reactions.
#
# (kernel 1):
# Loading weak rates for n<->p conversions.
#
# (kernel 1):
# Loading rates and bulding reactions.
#
# (kernel 2):
# Reaction Number   Reaction Name   Initial species   Final Species
#
# >    Reference
#
# 0                 n -> p          {n}               {p}            \
#
# >   Phys.Rept\
#
# >    . 754 (2018) 1-66
#
# 1                 np -> dg        {n, p}            {d, g}
#
# >    And06
#
# 2                 dp -> He3g      {d, p}            {He3, g}
#
# >    Moscoso2021
#
# 3                 dd -> He3n      {d, d}            {He3, n}
#
# >    Gom17
#
# 4                 dd -> tp        {d, d}            {t, p}
#
# >    Gom17
#
# 5                 tp -> ag        {t, p}            {a, g}
#
# >    Ser04
#
# 6                 td -> an        {t, d}            {a, n}
#
# >    deSouza19a
#
# 7                 ta -> Li7g      {t, a}            {Li7, g}
#
# >    DAACV04
#
# 8                 He3n -> tp      {He3, n}          {t, p}
#
# >    DAACV04
#
# 9                 He3d -> ap      {He3, d}          {a, p}
#
# >    deSouza19b
#
# 10                He3a -> Be7g    {He3, a}          {Be7, g}
#
# >    Ili16
#
# 11                Be7n -> Li7p    {Be7, n}          {Li7, p}
#
# >    deSouza2020
#
# 12                Li7p -> aa      {Li7, p}          {a, a}
#
# >    DAACV04
#
# (kernel 1):
# Reaction Number   Reaction Name   Initial species   Final Species
#
# >    Reference
#
# 0                 n -> p          {n}               {p}            \
#
# >   Phys.Rept\
#
# >    . 754 (2018) 1-66
#
# 1                 np -> dg        {n, p}            {d, g}
#
# >    And06
#
# 2                 dp -> He3g      {d, p}            {He3, g}
#
# >    Moscoso2021
#
# 3                 dd -> He3n      {d, d}            {He3, n}
#
# >    Gom17
#
# 4                 dd -> tp        {d, d}            {t, p}
#
# >    Gom17
#
# 5                 tp -> ag        {t, p}            {a, g}
#
# >    Ser04
#
# 6                 td -> an        {t, d}            {a, n}
#
# >    deSouza19a
#
# 7                 ta -> Li7g      {t, a}            {Li7, g}
#
# >    DAACV04
#
# 8                 He3n -> tp      {He3, n}          {t, p}
#
# >    DAACV04
#
# 9                 He3d -> ap      {He3, d}          {a, p}
#
# >    deSouza19b
#
# 10                He3a -> Be7g    {He3, a}          {Be7, g}
#
# >    Ili16
#
# 11                Be7n -> Li7p    {Be7, n}          {Li7, p}
#
# >    deSouza2020
#
# 12                Li7p -> aa      {Li7, p}          {a, a}
#
# >    DAACV04
#
# (kernel 2):
# Launching BBN numerics.
#
# (kernel 1):
# Launching BBN numerics.
#
# (kernel 2):
# I load compiled function from lib/DY18C_BBNRatesAC2022_small_network13.mx
#
# >    and the library linked is lib/DY18C_BBNRatesAC2022_small_network13.dylib
#
# (kernel 1):
# I load compiled function from lib/DY18C_BBNRatesAC2022_small_network13.mx
#
# >    and the library linked is lib/DY18C_BBNRatesAC2022_small_network13.dylib
#
# (kernel 2):
# I load compiled function from lib/DYC_BBNRatesAC2022_small_network13.mx
#
# >    and the library linked is lib/DYC_BBNRatesAC2022_small_network13.dylib
#
# (kernel 1):
# I load compiled function from lib/DYC_BBNRatesAC2022_small_network13.mx
#
# >    and the library linked is lib/DYC_BBNRatesAC2022_small_network13.dylib
#
# (kernel 2):
# Iteration 47  Memory usage = 76445544 time = 1.22863  Kernel : 2
#
# (kernel 2):
#            -11                      -6            -8            -6
# {1.88435 10   , 0.748431, 7.66811 10  , 2.34649 10  , 5.92429 10  ,
#
#                          -11            -9
# >   0.0628839, 1.12515 10   , 1.00503 10  }
#
# (kernel 1):
# Iteration 50  Memory usage = 76452400 time = 1.21989  Kernel : 1
#
# (kernel 1):
#            -11                     -6            -8            -6
# {1.86481 10   , 0.748366, 7.7105 10  , 2.31609 10  , 5.97435 10  , 0.0629003,\
#
# >
#
#               -11            -10
# >   1.00042 10   , 9.99025 10   }
#
# Table of results {{0.251601, 0.251589, 0.251692, 0.251386, 0.251925,
#
# >     0.251741, 0.25151, 0.251222, 0.251691, 0.251567, 0.251361, 0.251743,
#
# >     0.251641, 0.251476, 0.25154, 0.251569, 0.251514, 0.251536, 0.251549,
#
# >     0.251573, 0.251404, 0.251471, 0.251556, 0.251608, 0.251582, 0.251671,
#
# >     0.251441, 0.251575, 0.251471, 0.251619, 0.251585, 0.251474, 0.251411,
#
# >     0.25159, 0.251508, 0.251352, 0.251536, 0.251644, 0.25147, 0.251569,
#
# >     0.251768, 0.251471, 0.251537, 0.251528, 0.251447, 0.25147, 0.251535,
#
# >     0.251636, 0.251487, 0.251601},
#
# >    {0.0000101207, 0.0000104768, 0.000010542, 0.0000104786, 0.0000101734,
#
# >     0.00001026, 0.0000104279, 0.0000103801, 0.000010402, 0.0000104958,
#
#                                            -6
# >     0.0000103177, 0.0000102253, 9.9926 10  , 0.0000104199, 0.000010224,
#
# >     0.0000102926, 0.0000105137, 0.0000102966, 0.0000102755, 0.0000104037,
#
# >     0.0000104131, 0.0000101859, 0.0000103367, 0.0000101971, 0.000010136,
#
# >     0.0000103589, 0.0000101845, 0.0000102988, 0.0000101233, 0.0000100244,
#
# >     0.0000104243, 0.0000102514, 0.0000105117, 0.0000104175, 0.0000104003,
#
# >     0.0000104252, 0.0000106221, 0.0000102237, 0.0000102521, 0.0000102379,
#
# >     0.0000101811, 0.0000102872, 0.000010152, 0.0000101629, 0.0000105411,
#
# >     0.0000104273, 0.0000102456, 0.0000102865, 0.0000103264, 0.0000103031},
#
#                 -6            -6            -6            -6            -6
# >    {8.12479 10  , 8.03055 10  , 7.88553 10  , 8.02626 10  , 7.93457 10  ,
#
#                 -6            -6            -6            -6            -6
# >     7.97997 10  , 8.10801 10  , 8.04311 10  , 7.92662 10  , 8.01004 10  ,
#
#                 -6            -6            -6            -6            -6
# >     8.18207 10  , 8.04205 10  , 8.31382 10  , 8.01034 10  , 8.09334 10  ,
#
#                 -6            -6           -6            -6            -6
# >     8.02268 10  , 8.11305 10  , 7.9502 10  , 8.10132 10  , 8.11609 10  ,
#
#                 -6            -6            -6            -6            -6
# >     7.96028 10  , 8.01304 10  , 7.89444 10  , 8.20165 10  , 8.10081 10  ,
#
#                 -6            -6            -6           -6            -6
# >     7.83245 10  , 8.04382 10  , 7.83568 10  , 8.1702 10  , 8.22025 10  ,
#
#                 -6            -6            -6            -6            -6
# >     7.87716 10  , 7.83964 10  , 7.85372 10  , 8.05734 10  , 7.97462 10  ,
#
#                 -6            -6           -6            -6            -6
# >     8.02137 10  , 7.97393 10  , 8.1675 10  , 8.01446 10  , 8.00975 10  ,
#
#                 -6            -6            -6            -6            -6
# >     8.17741 10  , 7.98429 10  , 8.07085 10  , 8.22469 10  , 7.82983 10  ,
#
#                 -6            -6            -6            -6            -6
# >     8.00683 10  , 7.94696 10  , 7.93693 10  , 8.01138 10  , 8.01414 10  },
#
#                 -9            -9            -9            -9            -9
# >    {1.37802 10  , 1.34329 10  , 1.29878 10  , 1.31878 10  , 1.27666 10  ,
#
#                 -9            -9            -9            -9            -9
# >     1.35574 10  , 1.34783 10  , 1.33726 10  , 1.27757 10  , 1.28505 10  ,
#
#                 -9           -9           -9            -9            -9
# >     1.33814 10  , 1.3279 10  , 1.4148 10  , 1.30785 10  , 1.26537 10  ,
#
#                 -9            -9            -9            -9            -9
# >     1.34264 10  , 1.29704 10  , 1.28947 10  , 1.37213 10  , 1.37999 10  ,
#
#                 -9            -9            -9            -9            -9
# >     1.32903 10  , 1.36875 10  , 1.33318 10  , 1.32022 10  , 1.31801 10  ,
#
#                 -9            -9            -9            -9            -9
# >     1.28994 10  , 1.42656 10  , 1.27603 10  , 1.37157 10  , 1.35486 10  ,
#
#                -9            -9            -9            -9            -9
# >     1.2537 10  , 1.33219 10  , 1.28421 10  , 1.32162 10  , 1.25042 10  ,
#
#                -9            -9            -9            -9            -9
# >     1.3153 10  , 1.36498 10  , 1.40568 10  , 1.38039 10  , 1.34655 10  ,
#
#                 -9            -9            -9            -9            -9
# >     1.40588 10  , 1.28349 10  , 1.34141 10  , 1.41446 10  , 1.29268 10  ,
#
#                 -9            -9            -9            -9            -9
# >     1.27007 10  , 1.35788 10  , 1.31876 10  , 1.33479 10  , 1.34831 10  }}
# python read results are [[2.51600789e-01 2.51588613e-01 2.51691943e-01 2.51386140e-01
#   2.51924609e-01 2.51740890e-01 2.51509542e-01 2.51222432e-01
#   2.51691163e-01 2.51566963e-01 2.51360910e-01 2.51743281e-01
#   2.51640576e-01 2.51475600e-01 2.51540163e-01 2.51568735e-01
#   2.51513558e-01 2.51536414e-01 2.51549167e-01 2.51573379e-01
#   2.51404338e-01 2.51471291e-01 2.51556300e-01 2.51607912e-01
#   2.51582490e-01 2.51670505e-01 2.51441368e-01 2.51574575e-01
#   2.51470580e-01 2.51618614e-01 2.51584604e-01 2.51474325e-01
#   2.51411102e-01 2.51589916e-01 2.51508302e-01 2.51351719e-01
#   2.51535887e-01 2.51644349e-01 2.51469587e-01 2.51569254e-01
#   2.51767618e-01 2.51471228e-01 2.51536725e-01 2.51528387e-01
#   2.51446532e-01 2.51469757e-01 2.51535500e-01 2.51636392e-01
#   2.51487392e-01 2.51601012e-01]
#  [1.01207135e-05 1.04767666e-05 1.05420185e-05 1.04786167e-05
#   1.01733993e-05 1.02600358e-05 1.04279326e-05 1.03800716e-05
#   1.04019728e-05 1.04958294e-05 1.03176819e-05 1.02252688e-05
#   9.99259784e-06 1.04198534e-05 1.02240118e-05 1.02925869e-05
#   1.05137131e-05 1.02965804e-05 1.02754990e-05 1.04037159e-05
#   1.04131150e-05 1.01858992e-05 1.03367476e-05 1.01971407e-05
#   1.01360322e-05 1.03588681e-05 1.01844881e-05 1.02988371e-05
#   1.01233179e-05 1.00243900e-05 1.04243012e-05 1.02513525e-05
#   1.05116613e-05 1.04174575e-05 1.04003224e-05 1.04252442e-05
#   1.06221426e-05 1.02236681e-05 1.02520776e-05 1.02378910e-05
#   1.01810529e-05 1.02872079e-05 1.01519692e-05 1.01629217e-05
#   1.05410789e-05 1.04272737e-05 1.02455805e-05 1.02865303e-05
#   1.03263558e-05 1.03031184e-05]
#  [8.12479454e-06 8.03055125e-06 7.88552662e-06 8.02626320e-06
#   7.93457085e-06 7.97997405e-06 8.10801427e-06 8.04311043e-06
#   7.92662168e-06 8.01003644e-06 8.18206991e-06 8.04205290e-06
#   8.31381531e-06 8.01034164e-06 8.09334117e-06 8.02268416e-06
#   8.11305468e-06 7.95019991e-06 8.10131816e-06 8.11609090e-06
#   7.96028211e-06 8.01303678e-06 7.89444461e-06 8.20165324e-06
#   8.10080606e-06 7.83244797e-06 8.04381572e-06 7.83568352e-06
#   8.17019965e-06 8.22024687e-06 7.87716157e-06 7.83963529e-06
#   7.85371704e-06 8.05734256e-06 7.97462326e-06 8.02136750e-06
#   7.97393325e-06 8.16749945e-06 8.01445574e-06 8.00974698e-06
#   8.17740911e-06 7.98429024e-06 8.07084628e-06 8.22468628e-06
#   7.82983188e-06 8.00683353e-06 7.94695644e-06 7.93692818e-06
#   8.01138454e-06 8.01413945e-06]
#  [1.37802251e-09 1.34328593e-09 1.29878350e-09 1.31877560e-09
#   1.27665513e-09 1.35574443e-09 1.34782653e-09 1.33725563e-09
#   1.27756923e-09 1.28505248e-09 1.33814356e-09 1.32789855e-09
#   1.41480405e-09 1.30784698e-09 1.26536821e-09 1.34263783e-09
#   1.29703881e-09 1.28947346e-09 1.37212772e-09 1.37998724e-09
#   1.32902599e-09 1.36874870e-09 1.33318480e-09 1.32022074e-09
#   1.31801031e-09 1.28993761e-09 1.42655818e-09 1.27603465e-09
#   1.37157415e-09 1.35485524e-09 1.25369696e-09 1.33219183e-09
#   1.28421291e-09 1.32161598e-09 1.25041558e-09 1.31529637e-09
#   1.36497669e-09 1.40568141e-09 1.38038906e-09 1.34654518e-09
#   1.40587849e-09 1.28348955e-09 1.34141440e-09 1.41445935e-09
#   1.29268089e-09 1.27006732e-09 1.35788221e-09 1.31875554e-09
#   1.33479144e-09 1.34831063e-09]]

# %% [markdown]
# ### Results and plots

# %%
YPobs=0.2453
sigYPobs=0.0034

DHobs=2.527e-5
sigDHobs=0.030e-5

He3obsmin=0.9e-5
He3obsmax=1.3e-5

Li7obs=1.58e-10
sigLi7obs=0.3e-10

h2OmegaOverEta = 3.6529876e7
Meanh2Omega =   0.022425
sigh2Omega = 0.000136

etamin= (Meanh2Omega-sigh2Omega)/h2OmegaOverEta
etamax= (Meanh2Omega+sigh2Omega)/h2OmegaOverEta

# %%
YPvalues = results[:,0]
DHvalues = results[:,1]
He3values = results[:,2]
Li7values = results[:,3]

def calculate_means_and_stds(list_of_lists):
    means = np.array([np.mean(sublist) for sublist in list_of_lists])
    stds = np.array([np.std(sublist) for sublist in list_of_lists])
    return means, stds

YPmeans, YPsigmas = calculate_means_and_stds(YPvalues)
DHmeans, DHsigmas = calculate_means_and_stds(DHvalues)
He3means, He3sigmas = calculate_means_and_stds(He3values)
Li7means, Li7sigmas = calculate_means_and_stds(Li7values)

#YPmeans, YPsigmas

# %%
plt.plot(eta_values,YPmeans+YPsigmas,color='blue',linewidth=0.3)
plt.plot(eta_values,YPmeans-YPsigmas,color='blue',linewidth=0.3)
plt.fill_between(eta_values, YPmeans-YPsigmas, YPmeans+YPsigmas, color='blue', alpha=0.5,linewidth=0.001)

plt.fill_between(eta_values, YPobs-sigYPobs, YPobs+sigYPobs, color='green', alpha=0.3,linewidth=0.001)
plt.axvspan(etamin, etamax, color='gray', alpha=0.5)



plt.xlabel(r'$\eta$')
plt.xlim(1e-10,1e-9)
plt.xscale('log')
plt.ylabel(r'$Y_\mathrm{P}$')

# Adding a legend
#plt.legend()

# Display the plot
plt.show()

# %%
plt.plot(eta_values,DHmeans+DHsigmas,color='blue',linewidth=0.3)
plt.plot(eta_values,DHmeans-DHsigmas,color='blue',linewidth=0.3)
plt.fill_between(eta_values, DHmeans-DHsigmas, DHmeans+DHsigmas, color='blue', alpha=0.5,linewidth=0.001)

plt.fill_between(eta_values, DHobs-sigDHobs, DHobs+sigDHobs, color='green', alpha=0.3,linewidth=0.001)


plt.plot(eta_values,He3means+He3sigmas,color='blue',linewidth=0.3)
plt.plot(eta_values,He3means-He3sigmas,color='blue',linewidth=0.3)
plt.fill_between(eta_values, He3means-He3sigmas, He3means+He3sigmas, color='blue', alpha=0.5,linewidth=0.001)
plt.fill_between(eta_values, He3obsmin, He3obsmax, color='green', alpha=0.3,linewidth=0.001)

plt.axvspan(etamin, etamax, color='gray', alpha=0.5)

plt.xlabel(r'$\eta$')
plt.xlim(1e-10,1e-9)
plt.xscale('log')
plt.yscale('log')
plt.ylabel(r'${}^3\mathrm{He/H} \qquad \qquad \mathrm{D/H}$')

# Adding a legend
#plt.legend()

# Display the plot
plt.show()

# %%
plt.plot(eta_values,Li7means+Li7sigmas,color='blue',linewidth=0.3)
plt.plot(eta_values,Li7means-Li7sigmas,color='blue',linewidth=0.3)
plt.fill_between(eta_values, Li7means-Li7sigmas, Li7means+Li7sigmas, color='blue', alpha=0.5,linewidth=0.001)
plt.fill_between(eta_values, Li7obs-sigLi7obs, Li7obs+sigLi7obs, color='green', alpha=0.3,linewidth=0.001)

plt.axvspan(etamin, etamax, color='gray', alpha=0.5)

plt.xlabel(r'$\eta$')
plt.xlim(1e-10,1e-9)
plt.xscale('log')
plt.yscale('log')
plt.ylabel(r'${}^7 \mathrm{Li/H}$')

# Adding a legend
#plt.legend()

# Display the plot
plt.show()
